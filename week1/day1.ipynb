# %% [markdown]
# # Instant Gratification
#
# ## Your first Frontier LLM Project!
#
# Let's build a useful LLM solution - in a matter of minutes.
#
# By the end of this course, you will have built an autonomous Agentic AI solution with 7 agents that collaborate to solve a business problem. All in good time! We will start with something smaller...
#
# Our goal is to code a new kind of Web Browser. Give it a URL, and it will respond with a summary. The Reader's Digest of the internet!!
#
# Before starting, you should have completed the setup for [PC](../SETUP-PC.md) or [Mac](../SETUP-mac.md) and you hopefully launched this jupyter lab from within the project root directory, with your environment activated.
#
# ## If you're new to Jupyter Lab
#
# Welcome to the wonderful world of Data Science experimentation! Once you've used Jupyter Lab, you'll wonder how you ever lived without it. Simply click in each "cell" with code in it, such as the cell immediately below this text, and hit Shift+Return to execute that cell. As you wish, you can add a cell with the + button in the toolbar, and print values of variables, or try out variations.
#
# I've written a notebook called [Guide to Jupyter](Guide%20to%20Jupyter.ipynb) to help you get more familiar with Jupyter Labs, including adding Markdown comments, using `!` to run shell commands, and `tqdm` to show progress.
#
# If you prefer to work in IDEs like VSCode or Pycharm, they both work great with these lab notebooks too.
#
# ## If you'd like to brush up your Python
#
# I've added a notebook called [Intermediate Python](Intermediate%20Python.ipynb) to get you up to speed. But you should give it a miss if you already have a good idea what this code does:
# `yield from {book.get("author") for book in books if book.get("author")}`
#
# ## I am here to help
#
# If you have any problems at all, please do reach out.
# I'm available through the platform, or at ed@edwarddonner.com, or at https://www.linkedin.com/in/eddonner/ if you'd like to connect (and I love connecting!)
#
# ## More troubleshooting
#
# Please see the [troubleshooting](troubleshooting.ipynb) notebook in this folder to diagnose and fix common problems.
#
# ## If this is old hat!
#
# If you're already comfortable with today's material, please hang in there; you can move swiftly through the first few labs - we will get much more in depth as the weeks progress.
#
# ## Business value of these exercises
#
# A final thought. While I've designed these notebooks to be educational, I've also tried to make them enjoyable. We'll do fun things like have LLMs tell jokes and argue with each other. But fundamentally, my goal is to teach skills you can apply in business. I'll explain business implications as we go, and it's worth keeping this in mind: as you build experience with models and techniques, think of ways you could put this into action at work today. Please do contact me if you'd like to discuss more or if you have ideas to bounce off me.

# %%
# imports

import os
import requests
from dotenv import load_dotenv
from bs4 import BeautifulSoup
from IPython.display import Markdown, display
from openai import OpenAI

# If you get an error running this cell, then please head over to the troubleshooting notebook!

# %% [markdown]
# # Connecting to OpenAI
#
# The next cell is where we load in the environment variables in your `.env` file and connect to OpenAI.
#
# ## Troubleshooting if you have problems:
#
# Head over to the [troubleshooting](troubleshooting.ipynb) notebook in this folder for step by step code to identify the root cause and fix it!
#
# If you make a change, try restarting the "Kernel" (the python process sitting behind this notebook) by Kernel menu >> Restart Kernel and Clear Outputs of All Cells. Then try this notebook again, starting at the top.
#
# Or, contact me! Message me or email ed@edwarddonner.com and we will get this to work.
#
# Any concerns about API costs? See my notes in the README - costs should be minimal, and you can control it at every point. You can also use Ollama as a free alternative, which we discuss during Day 2.

# %%
# Load environment variables in a file called .env

load_dotenv()
api_key = os.getenv('OPENAI_API_KEY')

# Check the key

if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not api_key.startswith("sk-proj-"):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
elif api_key.strip() != api_key:
    print("An API key was found, but it looks like it might have space or tab characters at the start or end - please remove them - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")
# Out:
# No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!

# %%
openai = OpenAI()

# If this doesn't work, try Kernel menu >> Restart Kernel and Clear Outputs Of All Cells, then run the cells from the top of this notebook down.
# If it STILL doesn't work (horrors!) then please see the troubleshooting notebook, or try the below line instead:
# openai = OpenAI(api_key="your-key-here-starting-sk-proj-")

# %%
# A class to represent a Webpage
# If you're not familiar with Classes, check out the "Intermediate Python" notebook

class Website:
    """
    A utility class to represent a Website that we have scraped
    """

    def __init__(self, url):
        """
        Create this Website object from the given url using the BeautifulSoup library
        """
        self.url = url
        response = requests.get(url)
        soup = BeautifulSoup(response.content, 'html.parser')
        self.title = soup.title.string if soup.title else "No title found"
        for irrelevant in soup.body(["script", "style", "img", "input"]):
            irrelevant.decompose()
        self.text = soup.body.get_text(separator="\n", strip=True)

# %%
# Let's try one out

ed = Website("https://collinsbenda.com")
print(ed.title)
print(ed.text)
# Out:
# Atuhaire Collins Benda - Atuhaire Collins
# C.Benda
# Get In Touch
# Your
# Product
# _
# Partner
# Struggling to Bring
# Your Idea to Life?
# I provide tailored tech solutions that drive growth, streamline operations, and foster innovation.
# Get In Touch
# Case Studies
# →
# Trusted By
# Leading Startups and Innovators
# Empowering Visionaries to Achieve Success
# How I Can Help You
# Discover my diverse
# service offerings
# I provide a wide range of services designed to help your business thrive. Explore how I can support your growth.
# Carousel
# Carousel
# Skip to previous slide page
# Skip to next slide page
# Product Design
# Struggling to turn your vision into a tangible product? We transform your ideas into intuitive and visually appealing designs, ensuring a seamless user experience that meets your business goals.
# Product Development
# Facing challenges in building a robust and scalable software solution? Our full-stack development services cover everything from front-end to back-end, providing comprehensive solutions tailored to your specific needs
# Learning Facilitation
# Need to upskill your team but don't know where to start? Our expert-led training programs enhance your team's knowledge and skills, offering customized learning experiences for professional growth
# Consultation
# Unsure how to navigate the complexities of the digital landscape? Our strategic consulting services help you tackle business challenges, optimize operations, and make informed decisions for sustainable growth
# UI/UX Design
# Transform your ideas into intuitive and aesthetically pleasing designs. We focus on creating user-centric designs that are both functional and visually appealing.
# Fullstack Software Devt
# From front-end to back-end, we provide comprehensive software development services. Our expertise spans across various technologies to build robust and scalable solutions tailored to your business needs.
# Training
# Enhance your team's skills and knowledge with our expert-led training programs. We offer customized learning experiences that cater to different learning styles and professional goals.
# Consultation
# Leverage our expertise to overcome business challenges and drive growth. We offer strategic consulting services to help you navigate the complexities of the digital landscape and make informed decisions.
# Product Design
# Struggling to turn your vision into a tangible product? We transform your ideas into intuitive and visually appealing designs, ensuring a seamless user experience that meets your business goals.
# Product Development
# Facing challenges in building a robust and scalable software solution? Our full-stack development services cover everything from front-end to back-end, providing comprehensive solutions tailored to your specific needs
# Learning Facilitation
# Gain valuable insights into the well-being of your customer base and uncover growth opportunities.
# Consultation
# Unsure how to navigate the complexities of the digital landscape? Our strategic consulting services help you tackle business challenges, optimize operations, and make informed decisions for sustainable growth
# Tailored Expertise
# Empowering your business with
# cutting-edge solutions
# Whether you're looking to design a new product, develop a robust software solution, or enhance your team's skills, we provide the expertise to help you succeed. Discover how our services can transform your business and drive growth.
# Product Design
# Overcome the challenge of creating user-friendly, visually appealing products. We design products that are intuitive and engaging, ensuring your users have a seamless experience.
# Product Development
# Struggling with full-stack software development? We handle end-to-end development, ensuring your project is built efficiently and to the highest standard.
# Unlock Your Potential
# Discover how our innovative solutions can help you achieve your goals. Get started today and transform your business with our expert services.
# Get started
# Learn more
# →
# Stats
# Achievements & Impact
# in Numbers
# Our continuous effort and dedication are reflected in these remarkable statistics.
# Students Taught
# Products Launched
# Talks Delivered
# Projects Completed
# Expert Learning Facilitation
# Elevate Your Educational Experience with
# Professional Guidance and Advanced Tools
# Discover how my expertise and innovative learning tools can transform your educational journey. From personalized coaching to cutting-edge technology integration, let's make learning engaging and effective.
# Why Choose Me?
# Tailored Learning Experiences
# for Real-World Success
# Gain a full-spectrum understanding of software development, from initial idea conception and business validation to product design, development, deployment, and client management. I blend practical, real-world scenarios with business-focused training, including how to charge, manage clients, and navigate professional challenges. Enhance your skills and build your career with personalized learning and expert guidance.
# More Info
# Career-Oriented
# Acquire skills tailored to advance your career and ensure you remain competitive in the job market.
# Practical
# Master practical skills through formats designed for real-world usability and immediate application.
# Hands-On (Project Based)
# Solidify your knowledge by working on real projects that provide hands-on, practical experience.
# Entrepreneurial Mastery
# Learn to monetize your skills and transform them into profitable business ventures with actionable strategies.
# Afrocentric Insights
# Explore an Afrocentric learning model that integrates and values African cultural and contextual perspectives.
# Tailored Mentorship
# Benefit from individualized guidance and support to navigate your learning path and career progression.
# Visionary Voices
# Dynamic Talks on Tech & Innovation
# with Collins
# See the talks you missed   →
# FAQ
# The answers to your
# Frequent questions and answers
# What is Afrocentric Product Development?
# Afrocentric product development involves creating products that are culturally relevant and beneficial to African communities. It focuses on incorporating African cultural values, traditions, and perspectives into the design, development, and deployment of products.
# How do you ensure your products are culturally relevant?
# We conduct thorough market research and engage with local communities to understand their needs, preferences, and cultural contexts. This involves co-creation workshops, focus groups, and continuous feedback loops to ensure our products resonate with African consumers.
# Can you give examples of Afrocentric products you have developed?
# Yes, our portfolio includes a range of products such as educational platforms tailored for African curriculums, business management tools for local enterprises, and tech solutions that address unique challenges in African markets. Please visit our Portfolio/Works page for detailed case studies and examples.
# How do you involve local communities in the product development process?
# We actively involve local communities through participatory design methods, including workshops, user testing sessions, and collaboration with local stakeholders. This ensures that the products we develop meet the real needs and preferences of the communities they are intended to serve.
# What technologies do you use in your product development process?
# We leverage the latest technologies, including artificial intelligence, machine learning, and cloud computing, to create innovative solutions. Our approach is to adapt these technologies to suit local conditions and needs, ensuring they are accessible and impactful.
# BR
# RS
# BZ
# MM
# BT
# VE
# LR
# JM
# PL
# KY
# BN
# KM
# GU
# TO
# KI
# GH
# TD
# ZW
# MF
# MN
# PT
# AS
# CG
# BE
# IL
# NZ
# NI
# AI
# I agree to the
# Terms of Service
# and
# Privacy Policy
# .
# Submit
# C.Benda
# Navigation
# Contact Me
# About
# Team
# More Sites
# Labs
# Blog
# Stay updated
# Talks
# Case Studies
# Socials
# @github
# @linkedin
# @twitter
# @behance
# Terms and Conditions
# Style Guide
# Privacy policy
# NB:
# Respecting the sensitive nature of certain projects, I recognize the importance of maintaining confidentiality. While showcasing my portfolio, ​please be aware that some projects may be omitted or presented in a generalized manner to safeguard the proprietary and confidential information ​of the company and collaborators. Confidentiality is a top priority, and I am committed to upholding the trust placed in me during the course of ​these projects. If you have any specific inquiries or would like more information, please feel free to
# contact me directly
# ©
# Collins Benda Atuhaire. All rights reserved.

# %% [markdown]
# ## Types of prompts
#
# You may know this already - but if not, you will get very familiar with it!
#
# Models like GPT4o have been trained to receive instructions in a particular way.
#
# They expect to receive:
#
# **A system prompt** that tells them what task they are performing and what tone they should use
#
# **A user prompt** -- the conversation starter that they should reply to

# %%
# Define our system prompt - you can experiment with this later, changing the last sentence to 'Respond in markdown in Spanish."

system_prompt = "You are an assistant that analyzes the contents of a website \
and provides a short summary, ignoring text that might be navigation related. \
Respond in markdown."

# %%
# A function that writes a User Prompt that asks for summaries of websites:

def user_prompt_for(website):
    user_prompt = f"You are looking at a website titled {website.title}"
    user_prompt += "\nThe contents of this website is as follows; \
please provide a short summary of this website in markdown. \
If it includes news or announcements, then summarize these too.\n\n"
    user_prompt += website.text
    return user_prompt

# %%
print(user_prompt_for(ed))
# Out:
# You are looking at a website titled Atuhaire Collins Benda - Atuhaire Collins
# The contents of this website is as follows; please provide a short summary of this website in markdown. If it includes news or announcements, then summarize these too.
#
# C.Benda
# Get In Touch
# Your
# Product
# _
# Partner
# Struggling to Bring
# Your Idea to Life?
# I provide tailored tech solutions that drive growth, streamline operations, and foster innovation.
# Get In Touch
# Case Studies
# →
# Trusted By
# Leading Startups and Innovators
# Empowering Visionaries to Achieve Success
# How I Can Help You
# Discover my diverse
# service offerings
# I provide a wide range of services designed to help your business thrive. Explore how I can support your growth.
# Carousel
# Carousel
# Skip to previous slide page
# Skip to next slide page
# Product Design
# Struggling to turn your vision into a tangible product? We transform your ideas into intuitive and visually appealing designs, ensuring a seamless user experience that meets your business goals.
# Product Development
# Facing challenges in building a robust and scalable software solution? Our full-stack development services cover everything from front-end to back-end, providing comprehensive solutions tailored to your specific needs
# Learning Facilitation
# Need to upskill your team but don't know where to start? Our expert-led training programs enhance your team's knowledge and skills, offering customized learning experiences for professional growth
# Consultation
# Unsure how to navigate the complexities of the digital landscape? Our strategic consulting services help you tackle business challenges, optimize operations, and make informed decisions for sustainable growth
# UI/UX Design
# Transform your ideas into intuitive and aesthetically pleasing designs. We focus on creating user-centric designs that are both functional and visually appealing.
# Fullstack Software Devt
# From front-end to back-end, we provide comprehensive software development services. Our expertise spans across various technologies to build robust and scalable solutions tailored to your business needs.
# Training
# Enhance your team's skills and knowledge with our expert-led training programs. We offer customized learning experiences that cater to different learning styles and professional goals.
# Consultation
# Leverage our expertise to overcome business challenges and drive growth. We offer strategic consulting services to help you navigate the complexities of the digital landscape and make informed decisions.
# Product Design
# Struggling to turn your vision into a tangible product? We transform your ideas into intuitive and visually appealing designs, ensuring a seamless user experience that meets your business goals.
# Product Development
# Facing challenges in building a robust and scalable software solution? Our full-stack development services cover everything from front-end to back-end, providing comprehensive solutions tailored to your specific needs
# Learning Facilitation
# Gain valuable insights into the well-being of your customer base and uncover growth opportunities.
# Consultation
# Unsure how to navigate the complexities of the digital landscape? Our strategic consulting services help you tackle business challenges, optimize operations, and make informed decisions for sustainable growth
# Tailored Expertise
# Empowering your business with
# cutting-edge solutions
# Whether you're looking to design a new product, develop a robust software solution, or enhance your team's skills, we provide the expertise to help you succeed. Discover how our services can transform your business and drive growth.
# Product Design
# Overcome the challenge of creating user-friendly, visually appealing products. We design products that are intuitive and engaging, ensuring your users have a seamless experience.
# Product Development
# Struggling with full-stack software development? We handle end-to-end development, ensuring your project is built efficiently and to the highest standard.
# Unlock Your Potential
# Discover how our innovative solutions can help you achieve your goals. Get started today and transform your business with our expert services.
# Get started
# Learn more
# →
# Stats
# Achievements & Impact
# in Numbers
# Our continuous effort and dedication are reflected in these remarkable statistics.
# Students Taught
# Products Launched
# Talks Delivered
# Projects Completed
# Expert Learning Facilitation
# Elevate Your Educational Experience with
# Professional Guidance and Advanced Tools
# Discover how my expertise and innovative learning tools can transform your educational journey. From personalized coaching to cutting-edge technology integration, let's make learning engaging and effective.
# Why Choose Me?
# Tailored Learning Experiences
# for Real-World Success
# Gain a full-spectrum understanding of software development, from initial idea conception and business validation to product design, development, deployment, and client management. I blend practical, real-world scenarios with business-focused training, including how to charge, manage clients, and navigate professional challenges. Enhance your skills and build your career with personalized learning and expert guidance.
# More Info
# Career-Oriented
# Acquire skills tailored to advance your career and ensure you remain competitive in the job market.
# Practical
# Master practical skills through formats designed for real-world usability and immediate application.
# Hands-On (Project Based)
# Solidify your knowledge by working on real projects that provide hands-on, practical experience.
# Entrepreneurial Mastery
# Learn to monetize your skills and transform them into profitable business ventures with actionable strategies.
# Afrocentric Insights
# Explore an Afrocentric learning model that integrates and values African cultural and contextual perspectives.
# Tailored Mentorship
# Benefit from individualized guidance and support to navigate your learning path and career progression.
# Visionary Voices
# Dynamic Talks on Tech & Innovation
# with Collins
# See the talks you missed   →
# FAQ
# The answers to your
# Frequent questions and answers
# What is Afrocentric Product Development?
# Afrocentric product development involves creating products that are culturally relevant and beneficial to African communities. It focuses on incorporating African cultural values, traditions, and perspectives into the design, development, and deployment of products.
# How do you ensure your products are culturally relevant?
# We conduct thorough market research and engage with local communities to understand their needs, preferences, and cultural contexts. This involves co-creation workshops, focus groups, and continuous feedback loops to ensure our products resonate with African consumers.
# Can you give examples of Afrocentric products you have developed?
# Yes, our portfolio includes a range of products such as educational platforms tailored for African curriculums, business management tools for local enterprises, and tech solutions that address unique challenges in African markets. Please visit our Portfolio/Works page for detailed case studies and examples.
# How do you involve local communities in the product development process?
# We actively involve local communities through participatory design methods, including workshops, user testing sessions, and collaboration with local stakeholders. This ensures that the products we develop meet the real needs and preferences of the communities they are intended to serve.
# What technologies do you use in your product development process?
# We leverage the latest technologies, including artificial intelligence, machine learning, and cloud computing, to create innovative solutions. Our approach is to adapt these technologies to suit local conditions and needs, ensuring they are accessible and impactful.
# How do you measure the impact of your products?
# We use a range of metrics to measure the social, economic, and environmental impact of our products. This includes user feedback, community impact assessments, and sustainability audits to ensure our products contribute positively to African communities.
# Do you offer training or support for your products?
# Yes, we provide comprehensive training and support to ensure our products are fully utilized and beneficial. This includes user manuals, online tutorials, and dedicated customer support teams to assist with any queries or issues.
# What is your approach to sustainability in product development?
# We prioritize sustainable practices by using eco-friendly materials, minimizing waste, and ensuring our products have a low environmental footprint. We also focus on creating economic opportunities within local communities, fostering sustainable growth.
# How do I get started with one of your products?
# To get started, simply visit our Products/Services page to explore our offerings. You can sign up directly on our website, and our team will provide you with an enablement pack and guide you through the setup process.
# How can I collaborate with you or get involved in your projects?


# %% [markdown]
# ## Messages
#
# The API from OpenAI expects to receive messages in a particular structure.
# Many of the other APIs share this structure:
#
# ```
# [
#     {"role": "system", "content": "system message goes here"},
#     {"role": "user", "content": "user message goes here"}
# ]

# %%
# See how this function creates exactly the format above

def messages_for(website):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_for(website)}
    ]

# %%
messages_for(ed)
# Out:
# [{'role': 'system',
#   'content': 'You are an assistant that analyzes the contents of a website and provides a short summary, ignoring text that might be navigation related. Respond in markdown.'},
#  {'role': 'user',
#   'content': "You are looking at a website titled Atuhaire Collins Benda - Atuhaire Collins\nThe contents of this website is as follows; please provide a short summary of this website in markdown. If it includes news or announcements, then summarize these too.\n\nC.Benda\nGet In Touch\nYour\nProduct\n_\nPartner\nStruggling to Bring\nYour Idea to Life?\nI provide tailored tech solutions that drive growth, streamline operations, and foster innovation.\nGet In Touch\nCase Studies\n→\nTrusted By\nLeading Startups and Innovators\nEmpowering Visionaries to Achieve Success\nHow I Can Help You\nDiscover my diverse\nservice offerings\nI provide a wide range of services designed to help your business thrive. Explore how I can support your growth.\nCarousel\nCarousel\nSkip to previous slide page\nSkip to next slide page\nProduct Design\nStruggling to turn your vision into a tangible product? We transform your ideas into intuitive and visually appealing designs, ensuring a seamless user experience that meets your business goals.\nProduct Development\nFacing challenges in building a robust and scalable software solution? Our full-stack development services cover everything from front-end to back-end, providing comprehensive solutions tailored to your specific needs\nLearning Facilitation\nNeed to upskill your team but don't know where to start? Our expert-led training programs enhance your team's knowledge and skills, offering customized learning experiences for professional growth\nConsultation\nUnsure how to navigate the complexities of the digital landscape? Our strategic consulting services help you tackle business challenges, optimize operations, and make informed decisions for sustainable growth\nUI/UX Design\nTransform your ideas into intuitive and aesthetically pleasing designs. We focus on creating user-centric designs that are both functional and visually appealing.\nFullstack Software Devt\nFrom front-end to back-end, we provide comprehensive software development services. Our expertise spans across various technologies to build robust and scalable solutions tailored to your business needs.\nTraining\nEnhance your team's skills and knowledge with our expert-led training programs. We offer customized learning experiences that cater to different learning styles and professional goals.\nConsultation\nLeverage our expertise to overcome business challenges and drive growth. We offer strategic consulting services to help you navigate the complexities of the digital landscape and make informed decisions.\nProduct Design\nStruggling to turn your vision into a tangible product? We transform your ideas into intuitive and visually appealing designs, ensuring a seamless user experience that meets your business goals.\nProduct Development\nFacing challenges in building a robust and scalable software solution? Our full-stack development services cover everything from front-end to back-end, providing comprehensive solutions tailored to your specific needs\nLearning Facilitation\nGain valuable insights into the well-being of your customer base and uncover growth opportunities.\nConsultation\nUnsure how to navigate the complexities of the digital landscape? Our strategic consulting services help you tackle business challenges, optimize operations, and make informed decisions for sustainable growth\nTailored Expertise\nEmpowering your business with\ncutting-edge solutions\nWhether you're looking to design a new product, develop a robust software solution, or enhance your team's skills, we provide the expertise to help you succeed. Discover how our services can transform your business and drive growth.\nProduct Design\nOvercome the challenge of creating user-friendly, visually appealing products. We design products that are intuitive and engaging, ensuring your users have a seamless experience.\nProduct Development\nStruggling with full-stack software development? We handle end-to-end development, ensuring your project is built efficiently and to  ...

# %% [markdown]
# ## Time to bring it together - the API for OpenAI is very simple!

# %%
# And now: call the OpenAI API. You will get very familiar with this!

def summarize(url):
    website = Website(url)
    response = openai.chat.completions.create(
        model = "gpt-4o-mini",
        messages = messages_for(website)
    )
    return response.choices[0].message.content

# %%
summarize("https://edwarddonner.com")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 summarize("https://edwarddonner.com")
#
# Cell In[12], line 5, in summarize(url)
#       3 def summarize(url):
#       4     website = Website(url)
# ----> 5     response = openai.chat.completions.create(
#       6         model = "gpt-4o-mini",
#       7         messages = messages_for(website)
#       8     )
#       9     return response.choices[0].message.content
#
# NameError: name 'openai' is not defined

# %%
# A function to display this nicely in the Jupyter output, using markdown

def display_summary(url):
    summary = summarize(url)
    display(Markdown(summary))

# %%
display_summary("https://edwarddonner.com")

# %% [markdown]
# # Let's try more websites
#
# Note that this will only work on websites that can be scraped using this simplistic approach.
#
# Websites that are rendered with Javascript, like React apps, won't show up. See the community-contributions folder for a Selenium implementation that gets around this. You'll need to read up on installing Selenium (ask ChatGPT!)
#
# Also Websites protected with CloudFront (and similar) may give 403 errors - many thanks Andy J for pointing this out.
#
# But many websites will work just fine!

# %%
display_summary("https://cnn.com")

# %%
display_summary("https://anthropic.com")

# %% [markdown]
# ## Business Applications
#
# In this exercise, you experienced calling the API of a Frontier Model (a leading model at the frontier of AI) for the first time. This is broadly applicable across Gen AI use cases and we will be using APIs like OpenAI at many stages in the course, in addition to building our own LLMs.
#
# More specifically, we've applied this to Summarization - a classic Gen AI use case to make a summary. This can be applied to any business vertical - summarizing the news, summarizing financial performance, summarizing a resume in a cover letter - the applications are limitless. Consider how you could apply Summarization in your business, and try prototyping a solution.

# %% [markdown]
# ## An extra exercise for those who enjoy web scraping
#
# You may notice that if you try `display_summary("https://openai.com")` - it doesn't work! That's because OpenAI has a fancy website that uses Javascript. There are many ways around this that some of you might be familiar with. For example, Selenium is a hugely popular framework that runs a browser behind the scenes, renders the page, and allows you to query it. If you have experience with Selenium, Playwright or similar, then feel free to improve the Website class to use them. In the community-contributions folder, you'll find an example Selenium solution from a student (thank you!)

# %% [markdown]
# # Sharing your code
#
# I'd love it if you share your code afterwards so I can share it with others! You'll notice that some students have already made changes (including a Selenium implementation) which you will find in the community-contributions folder. If you'd like add your changes to that folder, submit a Pull Request with your new versions in that folder and I'll merge your changes.
#
# If you're not an expert with git (and I am not!) then GPT has given some nice instructions on how to submit a Pull Request. It's a bit of an involved process, but once you've done it once it's pretty clear. As a pro-tip: it's best if you clear the outputs of your Jupyter notebooks (Edit >> Clean outputs of all cells, and then Save) for clean notebooks.
#
# PR instructions courtesy of an AI friend: https://chatgpt.com/share/670145d5-e8a8-8012-8f93-39ee4e248b4c
